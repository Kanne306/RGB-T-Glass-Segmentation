# %%
import numpy as np
import matplotlib.pyplot as plt

img = np.load('/home/htyehg/htyehg/thesis/RGB-T-Glass-Segmentation/RGB-T-glass/test/agricultural/ABLS1825/temperature.npy')
print(img.shape)
print(img.dtype)
print(np.min(img))  # Corrected line
print(np.max(img))  # Corrected line
plt.imshow(img)
plt.show()
# Out:
# (480, 640)
# float64
# 24.992
# 30.3
